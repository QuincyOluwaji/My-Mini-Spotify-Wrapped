# %% [markdown]
# ## My Spotify Data Analysis Using Python, Excel and Tableau

# %% [markdown]
# Spotify is a digital music, podcast, and video streaming service that gives you access to millions of songs and other content from creators all over the world. It is one of the most popular streaming platforms.
#
# Every year, Spotify users receive their "Spotify Wrapped," which is a summary of their listening habits for the year. However, you don't have to wait until December to get a summary of your listening habits. There are apps like stats.fm that can help you analyze your data, or you can do it yourself.
#
# I have a stats.fm account, but I decided to analyze my data myself anyway. I used the data that I downloaded from Spotify last year when I subscribed to a stats.fm premium account. The data is not up to date, but I will make do with it.
#
# The data set contains my streaming data from 20th of February, 2020 to 7th of July, 2022. it contains 58,607 rows and 5 columns
#
# This project will include four stages:
#
# Importing libraries and dataset
#
# Data cleaning
#
# Analysis
#
# Visualization
#
# Explanation of each stage:
#
# Stage 1: Importing libraries and dataset
#
# In this stage, I will import the necessary libraries and the dataset into my programming environment. I will use Python for this project.
#
# Stage 2: Data cleaning
#
# In this stage, I will clean the data to remove any errors or inconsistencies. I will also check for duplicate and null entries and remove them.
#
# Stage 3: Analysis
#
# In this stage, I will analyze the data to identify patterns and trends. I will also use statistical methods to calculate summary statistics, such as the total number of streams per artist or the total time spent listening to each album.
#
# Stage 4: Visualization
#
# In this stage, I will create visualizations to communicate the results of my analysis. I will use charts and graphs to show the top artists, albums, and songs, as well as other interesting trends.
#
# I am excited to start this project and learn more about my listening habits. I am also curious to see what new insights I can gain from my data.

# %% [markdown]
# ### Stage 1: Importing of libraries and Dataset
#
# Here i imported all the libraries i would use for this project. A library is a collection of pre-written code used to optimize tasks. Every library is used to solve specific problems. For example the pandas and numpy libraries are used fo data analysis while the matplotlib is used for visualization.
#
# After importing the libraries, i will import the data which is in a json file.

# %%
# importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import os


#import plotly.graph_objects as go

# %% [markdown]
# Next i will import the data set which are json files

# %%
# importing the json data

Quin0 = open('endsong_0.json', encoding='utf8')
data = json.load(Quin0)

Quin1 = open('endsong_1.json', encoding='utf8')
data1 = json.load(Quin1)

Quin2 = open('endsong_2.json', encoding='utf8')
data2 = json.load(Quin2)

Quin3 = open('endsong_3.json', encoding='utf8')
data3 = json.load(Quin3)

# %%
print(data[:7])
print(data1[:7])
print(data2[:7])
print(data3[:7])
# Out:
# [{'ts': '2020-04-27T22:48:54Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'Android-tablet OS 9 API 28 (INFINIX MOBILITY LIMITED,   xyz  )', 'ms_played': 271215, 'conn_country': 'NG', 'ip_addr_decrypted': '41.190.2.188', 'user_agent_decrypted': 'unknown', 'master_metadata_track_name': 'Popo (How deep is our love?)', 'master_metadata_album_artist_name': 'Yerin Baek', 'master_metadata_album_album_name': 'Every letter I sent you.', 'spotify_track_uri': 'spotify:track:5XAJzwa0B2Hf8Rb1q0rowN', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': 'trackdone', 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1588027461324, 'incognito_mode': False}, {'ts': '2020-11-30T14:42:27Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'Android-tablet OS 9 API 28 (INFINIX MOBILITY LIMITED,   xyz  )', 'ms_played': 186168, 'conn_country': 'NG', 'ip_addr_decrypted': '41.190.30.186', 'user_agent_decrypted': 'unknown', 'master_metadata_track_name': 'Go Away', 'master_metadata_album_artist_name': 'Fireboy DML', 'master_metadata_album_album_name': 'APOLLO', 'spotify_track_uri': 'spotify:track:7HJkl4z2MXokJoGtWPL2pz', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': 'fwdbtn', 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1606747102303, 'incognito_mode': False}, {'ts': '2020-12-14T10:47:30Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'Android-tablet OS 9 API 28 (INFINIX MOBILITY LIMITED, Infinix X652)', 'ms_played': 215920, 'conn_country': 'NG', 'ip_addr_decrypted': '41.190.30.8', 'user_agent_decrypted': 'unknown', 'master_metadata_track_name': 'long story short', 'master_metadata_album_artist_name': 'Taylor Swift', 'master_metadata_album_album_name': 'evermore', 'spotify_track_uri': 'spotify:track:2o2sgVJIgFXk8GQjWTgI6U', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': 'trackdone', 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1607942633636, 'incognito_mode': False}, {'ts': '2022-01-06T12:32:26Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'Android OS 9 API 28 (INFINIX MOBILITY LIMITED, Infinix X652)', 'ms_played': 242093, 'conn_country': 'NG', 'ip_addr_decrypted': '197.210.47.19', 'user_agent_decrypted': 'unknown', 'master_metadata_track_name': 'Haunted', 'master_metadata_album_artist_name': 'Taylor Swift', 'master_metadata_album_album_name': 'Speak Now', 'spotify_track_uri': 'spotify:track:2YjKcFQ1vYFhQPgsmCOjss', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'clickrow', 'reason_end': 'trackdone', 'shuffle': True, 'skipped': None, 'offline': True, 'offline_timestamp': 1641470274855, 'incognito_mode': False}, {'ts': '2021-10-08T21:57:04Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'Android OS 9 API 28 (INFINIX MOBILITY LIMITED, Infinix X652)', 'ms_played': 203851, 'conn_country': 'NG', 'ip_addr_decrypted': '197.210.64.114', 'user_agent_decrypted': 'unknown', 'master_metadata_track_name': 'Million Reasons', 'master_metadata_album_artist_name': 'Lady Gaga', 'master_metadata_album_album_name': 'Joanne', 'spotify_track_uri': 'spotify:track:7dZ1Odmx9jWIweQSatnRqo', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'appload', 'reason_end': 'trackdone', 'shuffle': True, 'skipped': None, 'offline': True, 'offline_timestamp': 1633724805377, 'incognito_mode': False}, {'ts': '2020-05-08T10:30:55Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'Android-tablet OS 9 API 28 (INFINIX MOBILITY LIMITED,   xyz  )', 'ms_played': 244826, 'conn_country': 'NG', 'ip_addr_decrypted': '41.190.30.215', 'user_agent_decrypted': 'unknown', 'master_metadata_track_name': 'End Game', 'master_metadata_album_artist_name': 'Taylor Swift', 'master_metadata_a ...
# [{'ts': '2022-01-11T20:58:13Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'Android OS 9 API 28 (INFINIX MOBILITY LIMITED, Infinix X652)', 'ms_played': 624, 'conn_country': 'US', 'ip_addr_decrypted': '104.223.98.171', 'user_agent_decrypted': 'unknown', 'master_metadata_track_name': 'Touch It', 'master_metadata_album_artist_name': 'Ariana Grande', 'master_metadata_album_album_name': 'Dangerous Woman', 'spotify_track_uri': 'spotify:track:6WikCGNUbXFmXoLre7vjeW', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': 'fwdbtn', 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1641934690760, 'incognito_mode': False}, {'ts': '2022-03-01T00:26:59Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'Android OS 9 API 28 (INFINIX MOBILITY LIMITED, Infinix X652)', 'ms_played': 191333, 'conn_country': 'NG', 'ip_addr_decrypted': '102.89.34.40', 'user_agent_decrypted': 'unknown', 'master_metadata_track_name': 'Surfin’ (Lee Know, Changbin, Felix)', 'master_metadata_album_artist_name': 'Stray Kids', 'master_metadata_album_album_name': 'NOEASY', 'spotify_track_uri': 'spotify:track:1FdnsU6An1Ye3uBJe8j23c', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': 'trackdone', 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1646094225669, 'incognito_mode': False}, {'ts': '2021-12-23T10:31:36Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'Android OS 9 API 28 (INFINIX MOBILITY LIMITED, Infinix X652)', 'ms_played': 139162, 'conn_country': 'US', 'ip_addr_decrypted': '217.138.255.200', 'user_agent_decrypted': 'unknown', 'master_metadata_track_name': 'End Game', 'master_metadata_album_artist_name': 'Taylor Swift', 'master_metadata_album_album_name': 'reputation', 'spotify_track_uri': 'spotify:track:2x0WlnmfG39ZuDmstl9xfX', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': 'fwdbtn', 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1640255355051, 'incognito_mode': False}, {'ts': '2022-04-09T09:19:29Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'Android OS 9 API 28 (INFINIX MOBILITY LIMITED, Infinix X652)', 'ms_played': 34274, 'conn_country': 'NG', 'ip_addr_decrypted': '197.210.29.248', 'user_agent_decrypted': 'unknown', 'master_metadata_track_name': 'Start', 'master_metadata_album_artist_name': 'Ellie Goulding', 'master_metadata_album_album_name': 'Brightest Blue', 'spotify_track_uri': 'spotify:track:0y3IeTNZJ5UjeD3dexyfq8', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': 'endplay', 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1649495910787, 'incognito_mode': False}, {'ts': '2022-06-09T08:19:06Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'iOS 15.5 (iPhone11,6)', 'ms_played': 217173, 'conn_country': 'NG', 'ip_addr_decrypted': '102.89.44.180', 'user_agent_decrypted': 'unknown', 'master_metadata_track_name': 'Better Than Revenge', 'master_metadata_album_artist_name': 'Taylor Swift', 'master_metadata_album_album_name': 'Speak Now', 'spotify_track_uri': 'spotify:track:55mh9j2aB7xZ1Oh463gK8k', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': 'trackdone', 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1654762527319, 'incognito_mode': False}, {'ts': '2021-06-01T13:37:58Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'Android OS 9 API 28 (INFINIX MOBILITY LIMITED, Infinix X652)', 'ms_played': 3114, 'conn_country': 'NG', 'ip_addr_decrypted': '102.89.3.79', 'user_agent_decrypted': 'unknown', 'master_metadata_track_name': "I'm the One (feat. Justin Bieber, Quavo, Chance the Rapper & Lil Wayne)", 'master_metadata_album_artist_name': 'DJ Khaled', 'master_ ...
# [{'ts': '2021-01-09T13:08:05Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'Android-tablet OS 9 API 28 (INFINIX MOBILITY LIMITED, Infinix X652)', 'ms_played': 131863, 'conn_country': 'NG', 'ip_addr_decrypted': '41.190.2.153', 'user_agent_decrypted': 'unknown', 'master_metadata_track_name': 'Woman Like Me (feat. Nicki Minaj)', 'master_metadata_album_artist_name': 'Little Mix', 'master_metadata_album_album_name': 'LM5', 'spotify_track_uri': 'spotify:track:4wwiEpSDGxe4lkmBucnaZ8', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': 'unexpected-exit-while-paused', 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1610191403686, 'incognito_mode': False}, {'ts': '2021-10-23T09:05:47Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'Android OS 9 API 28 (INFINIX MOBILITY LIMITED, Infinix X652)', 'ms_played': 3770, 'conn_country': 'NG', 'ip_addr_decrypted': '41.190.30.56', 'user_agent_decrypted': 'unknown', 'master_metadata_track_name': 'ADMV - Versión Urbana', 'master_metadata_album_artist_name': 'Maluma', 'master_metadata_album_album_name': 'PAPI JUANCHO', 'spotify_track_uri': 'spotify:track:3LoNDgFKiaFYSyzhNESwo3', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': 'fwdbtn', 'shuffle': True, 'skipped': None, 'offline': True, 'offline_timestamp': 1634907130495, 'incognito_mode': False}, {'ts': '2021-06-01T12:36:19Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'Android OS 9 API 28 (INFINIX MOBILITY LIMITED, Infinix X652)', 'ms_played': 14080, 'conn_country': 'NG', 'ip_addr_decrypted': '102.89.3.156', 'user_agent_decrypted': 'unknown', 'master_metadata_track_name': 'New', 'master_metadata_album_artist_name': 'Daya', 'master_metadata_album_album_name': 'New', 'spotify_track_uri': 'spotify:track:4tERsdVCLtLtrGdFBf9DGC', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': 'fwdbtn', 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1622550958008, 'incognito_mode': False}, {'ts': '2020-11-16T07:20:38Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'Android-tablet OS 9 API 28 (INFINIX MOBILITY LIMITED,   xyz  )', 'ms_played': 2781, 'conn_country': 'NG', 'ip_addr_decrypted': '41.190.30.230', 'user_agent_decrypted': 'unknown', 'master_metadata_track_name': 'Like A Fool', 'master_metadata_album_artist_name': 'NIve', 'master_metadata_album_album_name': 'Like A Fool', 'spotify_track_uri': 'spotify:track:1E8Cztx0OIj4zm1IZh2XXj', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': 'fwdbtn', 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1605511233508, 'incognito_mode': False}, {'ts': '2021-12-24T12:05:15Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'Android OS 9 API 28 (INFINIX MOBILITY LIMITED, Infinix X652)', 'ms_played': 149997, 'conn_country': 'US', 'ip_addr_decrypted': '212.103.48.86', 'user_agent_decrypted': 'unknown', 'master_metadata_track_name': 'Lovesick Girls', 'master_metadata_album_artist_name': 'BLACKPINK', 'master_metadata_album_album_name': 'THE ALBUM', 'spotify_track_uri': 'spotify:track:4Ws314Ylb27BVsvlZOy30C', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': 'endplay', 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1640347354337, 'incognito_mode': False}, {'ts': '2021-10-12T08:37:00Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'Android OS 9 API 28 (INFINIX MOBILITY LIMITED, Infinix X652)', 'ms_played': 198893, 'conn_country': 'NG', 'ip_addr_decrypted': '41.190.30.243', 'user_agent_decrypted': 'unknown', 'master_metadata_track_name': 'Set Me Free', 'master_metadata_album_artist_name': 'The Chicks', 'master_metadata_album_album_name': 'Gaslighter' ...
# [{'ts': '2020-12-15T14:49:50Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'Android-tablet OS 9 API 28 (INFINIX MOBILITY LIMITED, Infinix X652)', 'ms_played': 118674, 'conn_country': 'NG', 'ip_addr_decrypted': '41.190.30.8', 'user_agent_decrypted': 'unknown', 'master_metadata_track_name': 'Sleeping Music (Deep Sleep)', 'master_metadata_album_artist_name': 'Deep Sleep Music Collective', 'master_metadata_album_album_name': 'Sleeping Music: Calm Music to Help You Sleep, Natural Sleep Aid and Relaxing Piano for Sleep Music', 'spotify_track_uri': 'spotify:track:2hIzjuxyItTpPuZZIULExJ', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'trackdone', 'reason_end': 'trackdone', 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1608043670189, 'incognito_mode': False}, {'ts': '2020-05-19T16:15:08Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'Android-tablet OS 9 API 28 (INFINIX MOBILITY LIMITED,   xyz  )', 'ms_played': 56007, 'conn_country': 'NG', 'ip_addr_decrypted': '41.190.30.203', 'user_agent_decrypted': 'unknown', 'master_metadata_track_name': 'everything i wanted', 'master_metadata_album_artist_name': 'Billie Eilish', 'master_metadata_album_album_name': 'everything i wanted', 'spotify_track_uri': 'spotify:track:3ZCTVFBt2Brf31RLEnCkWJ', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'clickrow', 'reason_end': 'endplay', 'shuffle': False, 'skipped': None, 'offline': False, 'offline_timestamp': 1589904849856, 'incognito_mode': False}, {'ts': '2020-11-21T09:36:06Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'Android-tablet OS 9 API 28 (INFINIX MOBILITY LIMITED,   xyz  )', 'ms_played': 1271, 'conn_country': 'NG', 'ip_addr_decrypted': '41.190.2.184', 'user_agent_decrypted': 'unknown', 'master_metadata_track_name': 'Are You Home?', 'master_metadata_album_artist_name': 'Amber Run', 'master_metadata_album_album_name': 'For a Moment, I Was Lost', 'spotify_track_uri': 'spotify:track:3evqB7FsIw9r4IqDYVim3U', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': 'fwdbtn', 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1605951363089, 'incognito_mode': False}, {'ts': '2022-01-11T21:06:08Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'Android OS 9 API 28 (INFINIX MOBILITY LIMITED, Infinix X652)', 'ms_played': 669, 'conn_country': 'US', 'ip_addr_decrypted': '104.223.98.171', 'user_agent_decrypted': 'unknown', 'master_metadata_track_name': 'Heartless', 'master_metadata_album_artist_name': 'The Weeknd', 'master_metadata_album_album_name': 'After Hours', 'spotify_track_uri': 'spotify:track:6bnF93Rx87YqUBLSgjiMU8', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': 'fwdbtn', 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1641935165831, 'incognito_mode': False}, {'ts': '2021-11-22T09:47:10Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'Android OS 9 API 28 (INFINIX MOBILITY LIMITED, Infinix X652)', 'ms_played': 232253, 'conn_country': 'NL', 'ip_addr_decrypted': '173.205.82.165', 'user_agent_decrypted': 'unknown', 'master_metadata_track_name': 'Delicate', 'master_metadata_album_artist_name': 'Taylor Swift', 'master_metadata_album_album_name': 'reputation', 'spotify_track_uri': 'spotify:track:6NFyWDv5CjfwuzoCkw47Xf', 'episode_name': None, 'episode_show_name': None, 'spotify_episode_uri': None, 'reason_start': 'fwdbtn', 'reason_end': 'trackdone', 'shuffle': True, 'skipped': None, 'offline': False, 'offline_timestamp': 1637574197652, 'incognito_mode': False}, {'ts': '2021-05-27T14:45:28Z', 'username': 'lf1e2m0ko4zhz7r9za98dwf4s', 'platform': 'Android OS 9 API 28 (INFINIX MOBILITY LIMITED, Infinix X652)', 'ms_played': 1279, 'conn_country': 'NG', 'ip_addr_decrypted': '41.190.31.62', 'user_agent_decrypted': 'unknown', ' ...

# %% [markdown]
# ### Stage 2: Data Cleaning
#
# The steps i will be taking in this stage includes:
#
# Step 1: Convert the data set from a json file to data frames
#
# Step 2: Join all 4 dataframes together
#
# Step 3: Change the end time column data type to a date-time data type
#
# Step 4: Convert the ms_played column from milliseconds to minutes then rename it
#
# Step 5: Check for null values
#
# Step 6: Check for duplcate values

# %%
# Step 1 : Converting the json files into dataframes. 
#          A json file is in a textual format which makes it hard to read.

streaming_data_1 = pd.DataFrame()

def extract_json_value(column_name):
    
    return [i[column_name] for i in data]
streaming_data_1['track_url'] = extract_json_value('spotify_track_uri')
streaming_data_1['artist_name'] = extract_json_value('master_metadata_album_artist_name')
streaming_data_1['end_time'] = extract_json_value('ts')
streaming_data_1['ms_played'] = extract_json_value('ms_played')
streaming_data_1['track_name'] = extract_json_value('master_metadata_track_name')
streaming_data_1['album_name'] = extract_json_value('master_metadata_album_album_name')

# %%
streaming_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15350 entries, 0 to 15349
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   track_url    15342 non-null  object
#  1   artist_name  15342 non-null  object
#  2   end_time     15350 non-null  object
#  3   ms_played    15350 non-null  int64
#  4   track_name   15342 non-null  object
#  5   album_name   15342 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 719.7+ KB

# %%
# Step 1: Converting the json files into dataframes

streaming_data_2 = pd.DataFrame()

def extract_json_value(column_name):
    
    return [i[column_name] for i in data1]

streaming_data_2['track_url'] = extract_json_value('spotify_track_uri')
streaming_data_2['artist_name'] = extract_json_value('master_metadata_album_artist_name')
streaming_data_2['end_time'] = extract_json_value('ts')
streaming_data_2['ms_played'] = extract_json_value('ms_played')
streaming_data_2['track_name'] = extract_json_value('master_metadata_track_name')
streaming_data_2['album_name'] = extract_json_value('master_metadata_album_album_name')

# %%
streaming_data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15323 entries, 0 to 15322
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   artist_name  15314 non-null  object
#  1   end_time     15323 non-null  object
#  2   ms_played    15323 non-null  int64
#  3   track_name   15314 non-null  object
#  4   album_name   15314 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 598.7+ KB

# %%
# Step 1: Converting the json files into a dataframe

streaming_data_3 = pd.DataFrame()

def extract_json_value(column_name):
    
    return [i[column_name] for i in data2]

streaming_data_['track_url'] = extract_json_value('spotify_track_uri')
streaming_data_3['artist_name'] = extract_json_value('master_metadata_album_artist_name')
streaming_data_3['end_time'] = extract_json_value('ts')
streaming_data_3['ms_played'] = extract_json_value('ms_played')
streaming_data_3['track_name'] = extract_json_value('master_metadata_track_name')
streaming_data_3['album_name'] = extract_json_value('master_metadata_album_album_name')

# %%
streaming_data_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15307 entries, 0 to 15306
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   artist_name  15295 non-null  object
#  1   end_time     15307 non-null  object
#  2   ms_played    15307 non-null  int64
#  3   track_name   15295 non-null  object
#  4   album_name   15295 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 598.1+ KB

# %%
# Step 1: Converting the json files into a dataframe

streaming_data_4 = pd.DataFrame()

def extract_json_value(column_name):
    
    return [i[column_name] for i in data3]

streaming_data_4['track_url'] = extract_json_value('spotify_track_uri')
streaming_data_4['artist_name'] = extract_json_value('master_metadata_album_artist_name')
streaming_data_4['end_time'] = extract_json_value('ts')
streaming_data_4['ms_played'] = extract_json_value('ms_played')
streaming_data_4['track_name'] = extract_json_value('master_metadata_track_name')
streaming_data_4['album_name'] = extract_json_value('master_metadata_album_album_name')

# %%
streaming_data_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12627 entries, 0 to 12626
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   artist_name  12622 non-null  object
#  1   end_time     12627 non-null  object
#  2   ms_played    12627 non-null  int64
#  3   track_name   12622 non-null  object
#  4   album_name   12622 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 493.4+ KB

# %% [markdown]
# Next i concat (which means to join) all 4 data frames together so i can view and analyze them all at once

# %%
# Step 2: concating the data frames

streaming_data = (pd.concat([streaming_data_1,streaming_data_2,streaming_data_3,streaming_data_4]))

# %%
streaming_data
# Out:
#                                   track_url   artist_name  \
# 0      spotify:track:5XAJzwa0B2Hf8Rb1q0rowN    Yerin Baek
# 1      spotify:track:7HJkl4z2MXokJoGtWPL2pz   Fireboy DML
# 2      spotify:track:2o2sgVJIgFXk8GQjWTgI6U  Taylor Swift
# 3      spotify:track:2YjKcFQ1vYFhQPgsmCOjss  Taylor Swift
# 4      spotify:track:7dZ1Odmx9jWIweQSatnRqo     Lady Gaga
# ...                                     ...           ...
# 12622  spotify:track:0ZNU020wNYvgW84iljPkPP  Taylor Swift
# 12623  spotify:track:14hJ5tc1VCFMWhVn9axRTC  Shawn Mendes
# 12624  spotify:track:6OKKfwf75kQ4veyLktYV7F  Selena Gomez
# 12625  spotify:track:5YqltLsjdqFtvqE7Nrysvs  Taylor Swift
# 12626  spotify:track:0Jlcvv8IykzHaSmj49uNW8  Taylor Swift
#
#                    end_time  ms_played  \
# 0      2020-04-27T22:48:54Z     271215
# 1      2020-11-30T14:42:27Z     186168
# 2      2020-12-14T10:47:30Z     215920
# 3      2022-01-06T12:32:26Z     242093
# 4      2021-10-08T21:57:04Z     203851
# ...                     ...        ...
# 12622  2020-12-01T07:29:11Z     313963
# 12623  2021-06-25T16:36:45Z       1428
# 12624  2020-04-23T08:31:18Z     184080
# 12625  2021-12-27T09:00:36Z     193146
# 12626  2021-01-06T09:58:55Z      41506
#
#                                               track_name  \
# 0                           Popo (How deep is our love?)
# 1                                                Go Away
# 2                                       long story short
# 3                                                Haunted
# 4                                        Million Reasons
# ...                                                  ...
# 12622                                         mirrorball
# 12623                                  Life Of The Party
# 12624                                           Only You
# 12625  We Are Never Ever Getting Back Together (Taylo...
# 12626                                              the 1
#
#                      album_name
# 0      Every letter I sent you.
# 1                        APOLLO
# 2                      evermore
# 3                     Speak Now
# 4                        Joanne
# ...                         ...
# 12622                  folklore
# 12623               Handwritten
# 12624            13 Reasons Why
# 12625    Red (Taylor's Version)
# 12626                  folklore
#
# [58607 rows x 6 columns]

# %%
# Step 3: changing end_time from object to datetime

streaming_data['end_time'] = pd.to_datetime(streaming_data['end_time'] )

# %%
# sorted the data using the end time column because i want
# to view the data from the first day to the last

streaming_data.sort_values('end_time', ascending = True)
# Out:
#                                   track_url               artist_name  \
# 7029   spotify:track:7FKbTRXXIWVFQmPH8zGfU0              Taylor Swift
# 15305  spotify:track:1kHEuJRasudLhjvnbfc4yS              Taylor Swift
# 36     spotify:track:2slqvGLwzZZYsT4K4Y1GBC              Taylor Swift
# 1770   spotify:track:1dGr1c8CrMLDpV6mPbImSI              Taylor Swift
# 4621   spotify:track:630sXRhIcfwr2e4RdNtjKN                 Zac Efron
# ...                                     ...                       ...
# 4343   spotify:track:3TcL0dyCMyr0kyTTc4NLgI  Selena Gomez & The Scene
# 6624   spotify:track:4upQnh3K5k1xbVOr97fdG7               Kizz Daniel
# 13575  spotify:track:3jjujdWJ72nww5eGnfs2E7              Harry Styles
# 8626   spotify:track:5x5JM1BSB6vollcIzDocqT               Miley Cyrus
# 7734   spotify:track:3cKM7UXBZmgjEgEBTkaIlU             One Direction
#
#                        end_time  ms_played  \
# 7029  2020-02-20 14:37:28+00:00     219385
# 15305 2020-02-20 15:11:00+00:00      43178
# 36    2020-02-20 15:12:24+00:00      35175
# 1770  2020-02-20 15:16:04+00:00     221306
# 4621  2020-02-20 15:16:54+00:00      46484
# ...                         ...        ...
# 4343  2022-07-07 23:51:53+00:00     195613
# 6624  2022-07-07 23:55:23+00:00      91792
# 13575 2022-07-07 23:55:24+00:00       1230
# 8626  2022-07-07 23:55:25+00:00       1184
# 7734  2022-07-07 23:59:50+00:00     184373
#
#                                         track_name                  album_name
# 7029                     The Man - Live From Paris                     The Man
# 15305                                  Blank Space                        1989
# 36     Only The Young - Featured in Miss Americana              Only The Young
# 1770                                         Lover                       Lover
# 4621                             Rewrite The Stars           Rewrite The Stars
# ...                                            ...                         ...
# 4343                                      Who Says      When The Sun Goes Down
# 6624                     Oshe (feat. The Cavemen.)                    Barnabas
# 13575                                    Adore You                   Fine Line
# 8626                                     The Climb       The Time Of Our Lives
# 7734                                        Strong  Midnight Memories (Deluxe)
#
# [58607 rows x 6 columns]

# %%
# step 4: converting from milliseconds to minutes and renaming the ms_played column

streaming_data['mins_played'] = streaming_data.ms_played.divide(60000)
streaming_data.drop('ms_played', axis=1, inplace=True)
streaming_data
# Out:
#                                   track_url   artist_name  \
# 0      spotify:track:5XAJzwa0B2Hf8Rb1q0rowN    Yerin Baek
# 1      spotify:track:7HJkl4z2MXokJoGtWPL2pz   Fireboy DML
# 2      spotify:track:2o2sgVJIgFXk8GQjWTgI6U  Taylor Swift
# 3      spotify:track:2YjKcFQ1vYFhQPgsmCOjss  Taylor Swift
# 4      spotify:track:7dZ1Odmx9jWIweQSatnRqo     Lady Gaga
# ...                                     ...           ...
# 12622  spotify:track:0ZNU020wNYvgW84iljPkPP  Taylor Swift
# 12623  spotify:track:14hJ5tc1VCFMWhVn9axRTC  Shawn Mendes
# 12624  spotify:track:6OKKfwf75kQ4veyLktYV7F  Selena Gomez
# 12625  spotify:track:5YqltLsjdqFtvqE7Nrysvs  Taylor Swift
# 12626  spotify:track:0Jlcvv8IykzHaSmj49uNW8  Taylor Swift
#
#                        end_time  \
# 0     2020-04-27 22:48:54+00:00
# 1     2020-11-30 14:42:27+00:00
# 2     2020-12-14 10:47:30+00:00
# 3     2022-01-06 12:32:26+00:00
# 4     2021-10-08 21:57:04+00:00
# ...                         ...
# 12622 2020-12-01 07:29:11+00:00
# 12623 2021-06-25 16:36:45+00:00
# 12624 2020-04-23 08:31:18+00:00
# 12625 2021-12-27 09:00:36+00:00
# 12626 2021-01-06 09:58:55+00:00
#
#                                               track_name  \
# 0                           Popo (How deep is our love?)
# 1                                                Go Away
# 2                                       long story short
# 3                                                Haunted
# 4                                        Million Reasons
# ...                                                  ...
# 12622                                         mirrorball
# 12623                                  Life Of The Party
# 12624                                           Only You
# 12625  We Are Never Ever Getting Back Together (Taylo...
# 12626                                              the 1
#
#                      album_name  mins_played
# 0      Every letter I sent you.     4.520250
# 1                        APOLLO     3.102800
# 2                      evermore     3.598667
# 3                     Speak Now     4.034883
# 4                        Joanne     3.397517
# ...                         ...          ...
# 12622                  folklore     5.232717
# 12623               Handwritten     0.023800
# 12624            13 Reasons Why     3.068000
# 12625    Red (Taylor's Version)     3.219100
# 12626                  folklore     0.691767
#
# [58607 rows x 6 columns]

# %% [markdown]
#      Note: Spotify counts time in milliseconds so i conveted the time of each stream to minutes.

# %%
#s Step 5: Checking for null values
pd.isnull(streaming_data).sum()
# Out:
# track_url      34
# artist_name    34
# end_time        0
# track_name     34
# album_name     34
# mins_played     0
# dtype: int64

# %% [markdown]
# There are 34 null values in the artist_name, track_name and album_name colums. These columns will not be usefull so i will delete them.

# %%
# drop null columns

streaming_data.dropna()
# Out:
#                                   track_url   artist_name  \
# 0      spotify:track:5XAJzwa0B2Hf8Rb1q0rowN    Yerin Baek
# 1      spotify:track:7HJkl4z2MXokJoGtWPL2pz   Fireboy DML
# 2      spotify:track:2o2sgVJIgFXk8GQjWTgI6U  Taylor Swift
# 3      spotify:track:2YjKcFQ1vYFhQPgsmCOjss  Taylor Swift
# 4      spotify:track:7dZ1Odmx9jWIweQSatnRqo     Lady Gaga
# ...                                     ...           ...
# 12622  spotify:track:0ZNU020wNYvgW84iljPkPP  Taylor Swift
# 12623  spotify:track:14hJ5tc1VCFMWhVn9axRTC  Shawn Mendes
# 12624  spotify:track:6OKKfwf75kQ4veyLktYV7F  Selena Gomez
# 12625  spotify:track:5YqltLsjdqFtvqE7Nrysvs  Taylor Swift
# 12626  spotify:track:0Jlcvv8IykzHaSmj49uNW8  Taylor Swift
#
#                        end_time  \
# 0     2020-04-27 22:48:54+00:00
# 1     2020-11-30 14:42:27+00:00
# 2     2020-12-14 10:47:30+00:00
# 3     2022-01-06 12:32:26+00:00
# 4     2021-10-08 21:57:04+00:00
# ...                         ...
# 12622 2020-12-01 07:29:11+00:00
# 12623 2021-06-25 16:36:45+00:00
# 12624 2020-04-23 08:31:18+00:00
# 12625 2021-12-27 09:00:36+00:00
# 12626 2021-01-06 09:58:55+00:00
#
#                                               track_name  \
# 0                           Popo (How deep is our love?)
# 1                                                Go Away
# 2                                       long story short
# 3                                                Haunted
# 4                                        Million Reasons
# ...                                                  ...
# 12622                                         mirrorball
# 12623                                  Life Of The Party
# 12624                                           Only You
# 12625  We Are Never Ever Getting Back Together (Taylo...
# 12626                                              the 1
#
#                      album_name  mins_played
# 0      Every letter I sent you.     4.520250
# 1                        APOLLO     3.102800
# 2                      evermore     3.598667
# 3                     Speak Now     4.034883
# 4                        Joanne     3.397517
# ...                         ...          ...
# 12622                  folklore     5.232717
# 12623               Handwritten     0.023800
# 12624            13 Reasons Why     3.068000
# 12625    Red (Taylor's Version)     3.219100
# 12626                  folklore     0.691767
#
# [58573 rows x 6 columns]

# %%
# Step 5: check for duplicates rows
duplicate = streaming_data[streaming_data.duplicated()]

# %%
# deleting duplicate rows
streaming_data.drop_duplicates()
# Out:
#                                   track_url   artist_name  \
# 0      spotify:track:5XAJzwa0B2Hf8Rb1q0rowN    Yerin Baek
# 1      spotify:track:7HJkl4z2MXokJoGtWPL2pz   Fireboy DML
# 2      spotify:track:2o2sgVJIgFXk8GQjWTgI6U  Taylor Swift
# 3      spotify:track:2YjKcFQ1vYFhQPgsmCOjss  Taylor Swift
# 4      spotify:track:7dZ1Odmx9jWIweQSatnRqo     Lady Gaga
# ...                                     ...           ...
# 12622  spotify:track:0ZNU020wNYvgW84iljPkPP  Taylor Swift
# 12623  spotify:track:14hJ5tc1VCFMWhVn9axRTC  Shawn Mendes
# 12624  spotify:track:6OKKfwf75kQ4veyLktYV7F  Selena Gomez
# 12625  spotify:track:5YqltLsjdqFtvqE7Nrysvs  Taylor Swift
# 12626  spotify:track:0Jlcvv8IykzHaSmj49uNW8  Taylor Swift
#
#                        end_time  \
# 0     2020-04-27 22:48:54+00:00
# 1     2020-11-30 14:42:27+00:00
# 2     2020-12-14 10:47:30+00:00
# 3     2022-01-06 12:32:26+00:00
# 4     2021-10-08 21:57:04+00:00
# ...                         ...
# 12622 2020-12-01 07:29:11+00:00
# 12623 2021-06-25 16:36:45+00:00
# 12624 2020-04-23 08:31:18+00:00
# 12625 2021-12-27 09:00:36+00:00
# 12626 2021-01-06 09:58:55+00:00
#
#                                               track_name  \
# 0                           Popo (How deep is our love?)
# 1                                                Go Away
# 2                                       long story short
# 3                                                Haunted
# 4                                        Million Reasons
# ...                                                  ...
# 12622                                         mirrorball
# 12623                                  Life Of The Party
# 12624                                           Only You
# 12625  We Are Never Ever Getting Back Together (Taylo...
# 12626                                              the 1
#
#                      album_name  mins_played
# 0      Every letter I sent you.     4.520250
# 1                        APOLLO     3.102800
# 2                      evermore     3.598667
# 3                     Speak Now     4.034883
# 4                        Joanne     3.397517
# ...                         ...          ...
# 12622                  folklore     5.232717
# 12623               Handwritten     0.023800
# 12624            13 Reasons Why     3.068000
# 12625    Red (Taylor's Version)     3.219100
# 12626                  folklore     0.691767
#
# [58260 rows x 6 columns]

# %% [markdown]
#  It is possible that columns like artist_name, track_name and album_name are duplicated because i could listen to an artist, song or album multiple times. hence why i looked for duplicate rows across all of the columns of the DataFrame and dropped them

# %% [markdown]
# After data cleaning, there are 58,257 rows left. i did not import the 'shuffle' and 'skipped' column because there were not enough rowS available for analysis.

# %% [markdown]
# ## Stage 3: Analysis
#
# Here i analyze the data frame. The questions i aim to answer include:
# 1) Who are my top 15 artist
# 2) What are my top 10 most streamed songs
# 3) What are my to 10 most played albums
# 4) What date did i listen to music the most
# 5) WHat day of the week did i listen to music the most
# 6) What year did i listen to music the most?

# %%
# Question 1: who are my top 15 artists based on total streams

streaming_data.groupby(['artist_name'])['track_name'].count().sort_values(ascending= False)[:15]
# Out:
# artist_name
# Taylor Swift      17650
# One Direction      1558
# Olivia Rodrigo     1132
# Harry Styles       1099
# BTS                1098
# Camila Cabello     1007
# Ed Sheeran         1000
# Little Mix          814
# ZAYN                780
# Ariana Grande       684
# Halsey              633
# Billie Eilish       623
# Lauv                580
# Katy Perry          551
# BLACKPINK           544
# Name: track_name, dtype: int64

# %% [markdown]
# It appears that Taylor Swift is my most streamed artist with a total of 17,650 streams followed by One direction with 1,558 streams. They both are my favourite artists so this comes as no surprise.

# %%
# Question 1b : Who are my top 15 artists based of minutes streamed

mins_listened = streaming_data.groupby(by='artist_name')['mins_played'].sum().sort_values(ascending=False)[:10]

mins_listened
# Out:
# artist_name
# Taylor Swift      56453.886700
# One Direction      3739.169833
# Olivia Rodrigo     3240.399017
# Harry Styles       3027.331483
# Camila Cabello     2583.564883
# BTS                2431.850233
# Little Mix         2000.582467
# Ed Sheeran         1797.139783
# ZAYN               1512.517217
# BLACKPINK          1422.257800
# Name: mins_played, dtype: float64

# %% [markdown]
# Once again, Taylor Swift is my most streamed artist. i spent 56, 453.88 minutes listening to her. that is roughly 941 hours.

# %%
#Question 2: What are my top 10 most streamed songs

top_tracks = streaming_data.groupby(['artist_name', 'track_name']).size().reset_index(name='count')
top_tracks = top_tracks.sort_values(by='count', ascending=False).head(10)

top_tracks
# Out:
#          artist_name                  track_name  count
# 5779    Taylor Swift                      willow    323
# 4418  Olivia Rodrigo             drivers license    274
# 5735    Taylor Swift          champagne problems    223
# 5511    Taylor Swift                 Blank Space    196
# 5682    Taylor Swift                     The Man    191
# 5732    Taylor Swift                    cardigan    189
# 5727    Taylor Swift                      august    183
# 5533    Taylor Swift                Cruel Summer    183
# 1110  Camila Cabello  Bam Bam (feat. Ed Sheeran)    178
# 5608    Taylor Swift                       Lover    178

# %%
#Question 3: What are my top 10 most played albums


top_albums = streaming_data.groupby(['artist_name', 'album_name']).size().reset_index(name='count')
top_albums = top_albums.sort_values(by='count', ascending=False).head(10)

top_albums
# Out:
#          artist_name                   album_name  count
# 3294    Taylor Swift                        Lover   2617
# 3320    Taylor Swift                     evermore   2178
# 3321    Taylor Swift                     folklore   1919
# 3274    Taylor Swift                         1989   1686
# 3301    Taylor Swift       Red (Taylor's Version)   1347
# 3303    Taylor Swift                    Speak Now   1208
# 3300    Taylor Swift                          Red   1105
# 3324    Taylor Swift                   reputation   1018
# 3287    Taylor Swift  Fearless (Taylor's Version)    877
# 2593  Olivia Rodrigo                         SOUR    874

# %%
# Question 4: What date did i listen to music the most

streaming_data['day'] = [d.date() for d in streaming_data['end_time']]
streaming_data['time'] = [d.time() for d in streaming_data['end_time']]
streaming_data.drop('end_time', axis=1, inplace=True)
streaming_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'end_time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 3
#       1 # Question 4: What date did i listen to music the most
# ----> 3 streaming_data['day'] = [d.date() for d in streaming_data['end_time']]
#       4 streaming_data['time'] = [d.time() for d in streaming_data['end_time']]
#       5 streaming_data.drop('end_time', axis=1, inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'end_time'

# %%
day = streaming_data.groupby(by=['day'], as_index=False).sum().sort_values('mins_played', ascending =False)
day
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_5360\3441094350.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   day = streaming_data.groupby(by=['day'], as_index=False).sum().sort_values('mins_played', ascending =False)
#             day  mins_played    year
# 314  2021-04-09  1177.370150  701287
# 551  2022-01-09   843.932417  679392
# 621  2022-03-22   754.310800  485280
# 350  2021-05-21   706.880283  549712
# 387  2021-07-05   685.149817  491103
# ..          ...          ...     ...
# 260  2021-02-05     0.077950    2021
# 628  2022-03-29     0.063633    2022
# 652  2022-04-23     0.016683    2022
# 682  2022-05-31     0.000000    2022
# 106  2020-06-12     0.000000    2020
#
# [719 rows x 3 columns]

# %% [markdown]
# This shows that i streamed music the most on April 9th, 2021. This was the day Taylor Swift released her first rerecorded album  Fearless TV so that makes perfect sense. Though i am surprised it was not November 12th, 2021 when she released her second rerecorded album Red TV.

# %%
# Question 5: What day of the week do i listen to music the most

streaming_data['day_of_the_week'] = pd.DatetimeIndex(streaming_data['day']).day_name()

streaming_data.head()
# Out:
#                               track_url   artist_name  \
# 0  spotify:track:5XAJzwa0B2Hf8Rb1q0rowN    Yerin Baek
# 1  spotify:track:7HJkl4z2MXokJoGtWPL2pz   Fireboy DML
# 2  spotify:track:2o2sgVJIgFXk8GQjWTgI6U  Taylor Swift
# 3  spotify:track:2YjKcFQ1vYFhQPgsmCOjss  Taylor Swift
# 4  spotify:track:7dZ1Odmx9jWIweQSatnRqo     Lady Gaga
#
#                      track_name                album_name  mins_played  \
# 0  Popo (How deep is our love?)  Every letter I sent you.     4.520250
# 1                       Go Away                    APOLLO     3.102800
# 2              long story short                  evermore     3.598667
# 3                       Haunted                 Speak Now     4.034883
# 4               Million Reasons                    Joanne     3.397517
#
#           day      time  year day_of_the_week
# 0  2020-04-27  22:48:54  2020          Monday
# 1  2020-11-30  14:42:27  2020          Monday
# 2  2020-12-14  10:47:30  2020          Monday
# 3  2022-01-06  12:32:26  2022        Thursday
# 4  2021-10-08  21:57:04  2021          Friday

# %%
day = streaming_data.groupby(by=['day_of_the_week'], as_index=False).sum().sort_values('mins_played', ascending =False)
day
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_5360\2309018048.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   day = streaming_data.groupby(by=['day_of_the_week'], as_index=False).sum().sort_values('mins_played', ascending =False)
#   day_of_the_week   mins_played      year
# 0          Friday  24168.243250  19626906
# 4        Thursday  20967.165633  18056308
# 5         Tuesday  19991.888367  19035693
# 1          Monday  19506.206250  16212282
# 6       Wednesday  17331.834050  14760834
# 2        Saturday  17274.462117  15914705
# 3          Sunday  16720.687800  14832491

# %% [markdown]
# i listen to music more on fridays than i do on other week days. Friday is the day new music get released every week. So i can attribute this habit to te fact that i check out new music on fridays. Sunday appears to be the day i stream the least. i have no reason why that is.

# %%
# Question 6: What year did i listen to music the most?
streaming_data['year'] = pd.DatetimeIndex(streaming_data['day']).year

streaming_data.head()
# Out:
#                               track_url   artist_name  \
# 0  spotify:track:5XAJzwa0B2Hf8Rb1q0rowN    Yerin Baek
# 1  spotify:track:7HJkl4z2MXokJoGtWPL2pz   Fireboy DML
# 2  spotify:track:2o2sgVJIgFXk8GQjWTgI6U  Taylor Swift
# 3  spotify:track:2YjKcFQ1vYFhQPgsmCOjss  Taylor Swift
# 4  spotify:track:7dZ1Odmx9jWIweQSatnRqo     Lady Gaga
#
#                      track_name                album_name  mins_played  \
# 0  Popo (How deep is our love?)  Every letter I sent you.     4.520250
# 1                       Go Away                    APOLLO     3.102800
# 2              long story short                  evermore     3.598667
# 3                       Haunted                 Speak Now     4.034883
# 4               Million Reasons                    Joanne     3.397517
#
#           day      time  year
# 0  2020-04-27  22:48:54  2020
# 1  2020-11-30  14:42:27  2020
# 2  2020-12-14  10:47:30  2020
# 3  2022-01-06  12:32:26  2022
# 4  2021-10-08  21:57:04  2021

# %%
years = streaming_data.groupby(by=['year'], as_index=False).sum().sort_values('mins_played', ascending =False)
years
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_5360\3093848049.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   years = streaming_data.groupby(by=['year'], as_index=False).sum().sort_values('mins_played', ascending =False)
#    year   mins_played
# 1  2021  58341.851200
# 0  2020  46531.284300
# 2  2022  31087.351967

# %% [markdown]
# I streamed music more in 2021 than i did in the other years. Though it is worth noting that the other years do not have complete data so this is not an accurate representation. 2020 is missing January data while 2022 is missing data from July 8th till year end.

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# The visualization for this project was done in Tableau. I visualized my top 5 artists, albums and songs, total number of songs I streamed how many minutes I spent streaming, my total streams and many more.
# Before visualizing in Tableau, I added 3 extra columns to the table using Power Query in Excel. The columns were namely: Artist Image, Track Image and Album Image. These columns contained URL links to each artist, album and track image.
# as I was using a function called Image Role in Tableau which requires me to have URLs that navigate to images not more than 200kb and some other requirements.
#
# The dashboard is available [here](https://public.tableau.com/app/profile/quincy.oluwaji/viz/MySpotifyAnalysis4/Story1?publish=yes)

# %% [markdown]
# ## Insights From My Visualisation

# %%
1) My data revealed that i stream music more  between 8am to 3pm. 9am -10am was the hour i streamed music the most.
2) 10th January 2022 - 16th January 2022 was the week i had streamed music the most.
3) I spent 135,960 minutes streaming which is 2266 hours of listening to music.
4) Based on total streams, BTS is my 5th most streamed artist but based on minutes listened, Camilla Cabello is my 5th most streamed artist.
